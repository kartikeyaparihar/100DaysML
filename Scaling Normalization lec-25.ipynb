# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the image
image_path = r"C:\Users\HP\Pictures\Screenshots\Screenshot 2025-02-19 195431.png"

img = mpimg.imread(image_path)

# Show the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the image
image_path = r"C:\Users\HP\Pictures\Screenshots\Screenshot 2025-02-19 201315.png"

img = mpimg.imread(image_path)

# Show the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the image
image_path = r"C:\Users\HP\Pictures\Screenshots\Screenshot 2025-02-19 201609.png"

img = mpimg.imread(image_path)

# Show the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('wine_data.csv',header=None,usecols=[0,1,2])
df.columns=['Class label', 'Alcohol', 'Malic acid']

# %%
df
# Out:
#      Class label  Alcohol  Malic acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
sns.kdeplot(df['Alcohol'])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.kdeplot(df['Malic acid'])
# Out:
# <Axes: xlabel='Malic acid', ylabel='Density'>

# %%
color_dict={1:'red',3:'green',2:'blue'}
sns.scatterplot(df['Alcohol'],df['Malic acid'],hue=df['Class label'],palette=color_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 color_dict={1:'red',3:'green',2:'blue'}
# ----> 2 sns.scatterplot(df['Alcohol'],df['Malic acid'],hue=df['Class label'],palette=color_dict)
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 2 keyword-only arguments) were given

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Class label', axis=1),
                                                    df['Class label'],
                                                    test_size=0.3,
                                                    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((124, 2), (54, 2))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(X_train)

# transform train and test sets
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
np.round(X_train.describe(), 1)
# Out:
#        Alcohol  Malic acid
# count    124.0       124.0
# mean      13.0         2.4
# std        0.8         1.1
# min       11.0         0.9
# 25%       12.4         1.6
# 50%       13.0         1.9
# 75%       13.6         3.2
# max       14.8         5.6

# %%
np.round(X_train_scaled.describe(), 1)
# Out:
#        Alcohol  Malic acid
# count    124.0       124.0
# mean       0.5         0.3
# std        0.2         0.2
# min        0.0         0.0
# 25%        0.4         0.2
# 50%        0.5         0.2
# 75%        0.7         0.5
# max        1.0         1.0

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(X_train['Alcohol'], X_train['Malic acid'],c=y_train)
ax1.set_title("Before Scaling")
ax2.scatter(X_train_scaled['Alcohol'], X_train_scaled['Malic acid'],c=y_train)
ax2.set_title("After Scaling")
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(X_train['Alcohol'], ax=ax1)
sns.kdeplot(X_train['Malic acid'], ax=ax1)

# after scaling
ax2.set_title('After Standard Scaling')
sns.kdeplot(X_train_scaled['Alcohol'], ax=ax2)
sns.kdeplot(X_train_scaled['Malic acid'], ax=ax2)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Alcohol Distribution Before Scaling')
sns.kdeplot(X_train['Alcohol'], ax=ax1)

# after scaling
ax2.set_title('Alcohol Distribution After Standard Scaling')
sns.kdeplot(X_train_scaled['Alcohol'], ax=ax2)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Malic acid Distribution Before Scaling')
sns.kdeplot(X_train['Malic acid'], ax=ax1)

# after scaling
ax2.set_title('Malic acid Distribution After Standard Scaling')
sns.kdeplot(X_train_scaled['Malic acid'], ax=ax2)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the image
image_path = r"C:\Users\HP\Pictures\Screenshots\Screenshot 2025-02-24 112736.png"

img = mpimg.imread(image_path)

# Show the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the image
image_path = r"C:\Users\HP\Pictures\Screenshots\Screenshot 2025-02-24 112244.png"

img = mpimg.imread(image_path)

# Show the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %% [markdown]
# # ROBUST SCALING

# %%
from sklearn.preprocessing import RobustScaler
robust = RobustScaler()
scaler.fit(X_train)

X_train_Robustscaled = scaler.transform(X_train)
X_test_Robustscaled = scaler.transform(X_test)

# %%
X_train_Robustscaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_Robustscaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
X_train_Robustscaled
# Out:
#       Alcohol  Malic acid
# 0    0.720430    0.203782
# 1    0.319892    0.084034
# 2    0.602151    0.712185
# 3    0.572581    0.563025
# 4    0.760753    0.130252
# ..        ...         ...
# 119  0.212366    0.174370
# 120  0.360215    0.058824
# 121  0.373656    0.151261
# 122  0.771505    0.165966
# 123  0.841398    0.340336
#
# [124 rows x 2 columns]

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(X_train['Alcohol'], ax=ax1)
sns.kdeplot(X_train['Malic acid'], ax=ax1)

# after scaling
ax2.set_title('After Standard Scaling')
sns.kdeplot(X_train_Robustscaled['Alcohol'], ax=ax2)
sns.kdeplot(X_train_Robustscaled['Malic acid'], ax=ax2)
plt.show()
